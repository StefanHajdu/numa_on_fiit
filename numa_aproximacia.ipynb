# %%
import numpy as np
import matplotlib.pyplot as plt
import numa as nm

def generate_random_exp_data():
    np.random.seed(20210706)
    x = np.arange(10)
    a = 4.5
    b = 0.5
    c = 50
    y = a * np.exp(b * x) + c
    y = y + np.random.normal(scale=np.sqrt(np.max(y)), size=len(x))
    return x, y

def scatter_plot_data(x, y):
    ax = plt.axes()
    ax.scatter(x, y)
    ax.set_title('Example Data')
    ax.set_ylabel('y-Values')
    ax.set_ylim(0, 500)
    ax.set_xlabel('x-Values')

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([0.6, 1.9, 4.3, 7.6, 12.6])
nm.fit_defined_curve(x, y, method='exp')
# Out:
# Parameters:
# {'a': 0.5818151616628182, 'c': 0.6987632088800599}
# Exp function: 0.6987632088800599*e^(0.5818151616628182x)
#
# L2 error:
# 0.8628081215271689

# %%
nm.fit_defined_curve(x, y, method='parabola')
# Out:
# Parameters:
# {'a': 0.5928571428562552, 'b': -0.587142857146322, 'c': 0.6399999999992206}
# Parabola function: 0.5928571428562552x^2 + -0.587142857146322x + 0.6399999999992206
#
# L2 error:
# 0.050285714285714316

# %%
nm.fit_defined_curve(x, y, method='line')
# Out:
# Parameters:
# {'a': 2.970000010516106, 'b': -3.510000031548318}
# Line function: 2.970000010516106x + -3.510000031548318
#
# L2 error:
# 4.971000000000002

# %% [markdown]
# ---

# %%
x = np.array([-5, -4, -1, 2, 3, 4])
y = np.array([-12.374, -11.161, -5.857, -0.009, 5.226, 7.252])
nm.fit_defined_curve(x, y, method='line')
# Out:
# Parameters:
# {'a': 2.177202352260128, 'b': -2.457632936439553}
# Line function: 2.177202352260128x + -2.457632936439553
#
# L2 error:
# 8.394704432941174

# %%
nm.fit_defined_curve(x, y, method='exp')
# Out:
# Parameters:
# {'a': 0.9054226424374138, 'c': 0.20863800497990945}
# Exp function: 0.20863800497990945*e^(0.9054226424374138x)
#
# L2 error:
# 319.4063688011893

# %%
nm.fit_defined_curve(x, y, method='parabola')
# Out:
# Parameters:
# {'a': 0.13665399385372357, 'b': 2.3299332872532856, 'c': -4.049250046093962}
# Parabola function: 0.13665399385372357x^2 + 2.3299332872532856x + -4.049250046093962
#
# L2 error:
# 2.673773403348694

# %% [markdown]
# ---

# %%
x = np.array([-5, -4, -3, -1, 2, 4])
y = np.array([-0.537, 0.664, -0.967, 1.783, 1.693, 4.431])
nm.fit_defined_curve(x, y, method='line')
# Out:
# Parameters:
# {'a': 0.4854403183012648, 'b': 1.7441803713544086}
# Line function: 0.4854403183012648x + 1.7441803713544086
#
# L2 error:
# 4.212885151193634

# %%
nm.fit_defined_curve(x, y, method='parabola')
# Out:
# Parameters:
# {'a': 0.043498042396691305, 'b': 0.5284768430089026, 'c': 1.27966281512666}
# Parabola function: 0.043498042396691305x^2 + 0.5284768430089026x + 1.27966281512666
#
# L2 error:
# 3.582205303762414

# %%
nm.fit_defined_curve(x, y, method='exp')
# Out:
# Parameters:
# {'a': 0.39643873602865, 'c': 0.8981357251311121}
# Exp function: 0.8981357251311121*e^(0.39643873602865x)
#
# L2 error:
# 3.682398587321303

# %% [markdown]
# ---

# %%
x = np.array([-1, 0, 2, 3, 4, 5])
y = np.array([0.684, -0.871, -6.100, -6.745, -9.875, -12.955])
nm.fit_defined_curve(x, y, method='line')
# Out:
# Parameters:
# {'a': -2.2245838528876574, 'b': -1.1570683147060643}
# Line function: -2.2245838528876574x + -1.1570683147060643
#
# L2 error:
# 2.1399141863354023

# %%
nm.fit_defined_curve(x, y, method='parabola')
# Out:
# Parameters:
# {'a': -0.09001547619285266, 'b': -1.8762630952443726, 'c': -1.0866214285759765}
# Parabola function: -0.09001547619285266x^2 + -1.8762630952443726x + -1.0866214285759765
#
# L2 error:
# 1.5480585166666652

# %%
nm.fit_defined_curve(x, y, method='exp')
# Out:
# Parameters:
# {'a': 0.37416231380677073, 'c': -2.093598658518605}
# Exp function: -2.093598658518605*e^(0.37416231380677073x)
#
# L2 error:
# 9.594339564418881

# %% [markdown]
# ---

# %%
x = np.array([1, 2, 3, 4, 6, 7])
y = np.array([5.002, 7.008, 11.210, 19.494, 69.659, 137.338])
nm.fit_defined_curve(x, y, method='line')
# Out:
# Parameters:
# {'a': 20.598204968986845, 'b': -37.341285714369334}
# Line function: 20.598204968986845x + -37.341285714369334
#
# L2 error:
# 2516.3085223726694

# %%
nm.fit_defined_curve(x, y, method='parabola')
# Out:
# Parameters:
# {'a': 5.519244047628908, 'b': -24.27564880957896, 'c': 28.889642857203736}
# Parabola function: 5.519244047628908x^2 + -24.27564880957896x + 28.889642857203736
#
# L2 error:
# 291.25408063095205

# %%
nm.fit_defined_curve(x, y, method='exp')
# Out:
# Parameters:
# {'a': 0.6490375923580979, 'c': 1.453453500968445}
# Exp function: 1.453453500968445*e^(0.6490375923580979x)
#
# L2 error:
# 12.332007783806073
